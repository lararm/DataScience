# %%
import json
import requests
import pandas as pd

# %%
response = requests.get('https://services.arcgis.com/S9th0jAJ7bqgIRjw/arcgis/rest/services/KSI/FeatureServer/0/query?where=1%3D1&outFields=*&outSR=4326&f=json')

# %%
data = json.loads(response.text)

# %%
attr = []

# %%
for i in range(0,len(data['features'])):
    # print(data['features'][i]['attributes'])
    attr.append(data['features'][i]['attributes'])

# %%
print(attr)
# Out:
# [{'Index_': 5245961, 'ACCNUM': '1107460', 'YEAR': 2009, 'DATE': 1245643200000, 'TIME': '0', 'Hour': 0, 'STREET1': 'F G GARDINER XY  E', 'STREET2': 'KIPLING AVE', 'OFFSET': ' ', 'ROAD_CLASS': 'Expressway', 'District': 'Etobicoke York', 'LATITUDE': 43.61804538, 'LONGITUDE': -79.52479029, 'LOCCOORD': 'Mid-Block', 'ACCLOC': ' ', 'TRAFFCTL': 'No Control', 'VISIBILITY': 'Clear', 'LIGHT': 'Daylight', 'RDSFCOND': 'Dry', 'ACCLASS': 'Non-Fatal Injury', 'IMPACTYPE': 'Sideswipe', 'INVTYPE': 'Motorcycle Driver', 'INVAGE': '25 to 29', 'INJURY': 'Major', 'FATAL_NO': 0, 'INITDIR': 'East', 'VEHTYPE': 'Motorcycle', 'MANOEUVER': 'Going Ahead', 'DRIVACT': 'Driving Properly', 'DRIVCOND': 'Normal', 'PEDTYPE': ' ', 'PEDACT': ' ', 'PEDCOND': ' ', 'CYCLISTYPE': ' ', 'CYCACT': ' ', 'CYCCOND': ' ', 'PEDESTRIAN': ' ', 'CYCLIST': ' ', 'AUTOMOBILE': 'Yes', 'MOTORCYCLE': 'Yes', 'TRUCK': ' ', 'TRSN_CITY_VEH': ' ', 'EMERG_VEH': ' ', 'PASSENGER': ' ', 'SPEEDING': 'Yes', 'AG_DRIV': 'Yes', 'REDLIGHT': ' ', 'ALCOHOL': ' ', 'DISABILITY': ' ', 'Division': 'D22', 'Ward_Name': 'Etobicoke-Lakeshore (6)', 'Ward_ID': 6, 'Hood_ID': 17, 'Hood_Name': 'Mimico (includes Humber Bay Shores) (17)', 'FID': 1}, {'Index_': 80194581, 'ACCNUM': '5000613755', 'YEAR': 2015, 'DATE': 1428984000000, 'TIME': '115', 'Hour': 1, 'STREET1': '7 INVERLEIGH DR', 'STREET2': ' ', 'OFFSET': ' ', 'ROAD_CLASS': 'Local', 'District': 'Etobicoke York', 'LATITUDE': 43.62590368, 'LONGITUDE': -79.49511347, 'LOCCOORD': 'Mid-Block', 'ACCLOC': 'At/Near Private Drive', 'TRAFFCTL': 'No Control', 'VISIBILITY': 'Clear', 'LIGHT': 'Dark, artificial', 'RDSFCOND': 'Dry', 'ACCLASS': 'Non-Fatal Injury', 'IMPACTYPE': 'Pedestrian Collisions', 'INVTYPE': 'Driver', 'INVAGE': '35 to 39', 'INJURY': ' ', 'FATAL_NO': 0, 'INITDIR': 'North', 'VEHTYPE': 'Automobile, Station Wagon', 'MANOEUVER': 'Going Ahead', 'DRIVACT': 'Other', 'DRIVCOND': 'Unknown', 'PEDTYPE': ' ', 'PEDACT': ' ', 'PEDCOND': ' ', 'CYCLISTYPE': ' ', 'CYCACT': ' ', 'CYCCOND': ' ', 'PEDESTRIAN': 'Yes', 'CYCLIST': ' ', 'AUTOMOBILE': 'Yes', 'MOTORCYCLE': ' ', 'TRUCK': ' ', 'TRSN_CITY_VEH': ' ', 'EMERG_VEH': ' ', 'PASSENGER': ' ', 'SPEEDING': ' ', 'AG_DRIV': ' ', 'REDLIGHT': ' ', 'ALCOHOL': ' ', 'DISABILITY': ' ', 'Division': 'D22', 'Ward_Name': 'Etobicoke-Lakeshore (5)', 'Ward_ID': 5, 'Hood_ID': 16, 'Hood_Name': 'Stonegate-Queensway (16)', 'FID': 2}, {'Index_': 5245962, 'ACCNUM': '1107460', 'YEAR': 2009, 'DATE': 1245643200000, 'TIME': '0', 'Hour': 0, 'STREET1': 'F G GARDINER XY  E', 'STREET2': 'KIPLING AVE', 'OFFSET': ' ', 'ROAD_CLASS': 'Expressway', 'District': 'Etobicoke York', 'LATITUDE': 43.61804538, 'LONGITUDE': -79.52479029, 'LOCCOORD': 'Mid-Block', 'ACCLOC': ' ', 'TRAFFCTL': 'No Control', 'VISIBILITY': 'Clear', 'LIGHT': 'Daylight', 'RDSFCOND': 'Dry', 'ACCLASS': 'Non-Fatal Injury', 'IMPACTYPE': 'Sideswipe', 'INVTYPE': 'Driver', 'INVAGE': '40 to 44', 'INJURY': 'None', 'FATAL_NO': 0, 'INITDIR': 'East', 'VEHTYPE': 'Automobile, Station Wagon', 'MANOEUVER': 'Changing Lanes', 'DRIVACT': 'Improper Lane Change', 'DRIVCOND': 'Normal', 'PEDTYPE': ' ', 'PEDACT': ' ', 'PEDCOND': ' ', 'CYCLISTYPE': ' ', 'CYCACT': ' ', 'CYCCOND': ' ', 'PEDESTRIAN': ' ', 'CYCLIST': ' ', 'AUTOMOBILE': 'Yes', 'MOTORCYCLE': 'Yes', 'TRUCK': ' ', 'TRSN_CITY_VEH': ' ', 'EMERG_VEH': ' ', 'PASSENGER': ' ', 'SPEEDING': 'Yes', 'AG_DRIV': 'Yes', 'REDLIGHT': ' ', 'ALCOHOL': ' ', 'DISABILITY': ' ', 'Division': 'D22', 'Ward_Name': 'Etobicoke-Lakeshore (6)', 'Ward_ID': 6, 'Hood_ID': 17, 'Hood_Name': 'Mimico (includes Humber Bay Shores) (17)', 'FID': 3}, {'Index_': 80194582, 'ACCNUM': '5000613755', 'YEAR': 2015, 'DATE': 1428984000000, 'TIME': '115', 'Hour': 1, 'STREET1': '7 INVERLEIGH DR', 'STREET2': ' ', 'OFFSET': ' ', 'ROAD_CLASS': 'Local', 'District': 'Etobicoke York', 'LATITUDE': 43.62590368, 'LONGITUDE': -79.49511347, 'LOCCOORD': 'Mid-Block', 'ACCLOC': 'At/Near Private Drive', 'TRAFFCTL': 'No Control', 'VISIBILITY': 'Clear', 'LIGHT': 'Dark, artificial', 'RDSFCOND': 'Dry', 'ACCLASS': 'Non-Fatal Injury',  ...

# %%
df = pd.DataFrame(attr)

# %%
df.shape
# Out:
# (2000, 55)
