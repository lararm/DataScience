# %%
#Libraries:
#Requests will allow you to send HTTP/1.1 requests using Python. With it, you can add content like headers, form data, multipart files, and parameters via simple Python libraries. It also allows you to access the response data of Python in the same way.
#BeautifulSoup


import requests
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import time

URL = "https://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=Toronto&start=10"
#conducting a request of the stated URL above:
page = requests.get(URL)
#specifying a desired format of “page” using the html parser - this allows python to read the various components of the page, rather than treating it as one long string.
soup = BeautifulSoup(page.text, "html.parser")
#printing soup in a more structured tree format that makes for easier reading
#print(soup.prettify())

# %%
def extract_job_title_from_result(soup): 
    jobs = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
            jobs.append(a["title"])
    return(jobs)


extract_job_title_from_result(soup)
# Out:
# ['Operations Research Analyst with DoD Secret or TS Clearance',
#  'Data Scientist (Relocation to Saudi Arabia)',
#  'Data Scientist - Labor Planning & Analytics',
#  'Operations Research Scientist',
#  'Data Scientist',
#  'Market Research Analyst - Technical',
#  'AML/KYC Data Scientist',
#  'Predictive Modeling Actuary – Multiple Positions Available',
#  'Sales Account Executive - Machine Learning – (Remote)',
#  'Pathology Surveyor',
#  'Business Intelligence Engineer (f/m) (relocated to Germany)',
#  'Google Cloud Solutions Architect',
#  'Predictive Modeling Actuary, P&C']

# %%
def extract_company_from_result(soup): 
    companies = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        company = div.find_all(name="span", attrs={"class":"company"})
        if len(company) > 0:
            for b in company:
                companies.append(b.text.strip())
        else:
            sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
            for span in sec_try:
                companies.append(span.text.strip())
    return(companies)

extract_company_from_result(soup)
# Out:
# ['DSoft Technology, Engineering and Analysis, Inc.',
#  'Saudi Aramco',
#  "DICK'S Sporting Goods",
#  'Fedex Ground',
#  'FedEx Services',
#  "DICK'S Sporting Goods",
#  'IBM',
#  'DW Simpson Global Actuarial Recruitment',
#  'Cvedia PTE. LTD.',
#  'The Joint Commission',
#  'Avira Operations GmbH & Co. KG',
#  'Pythian',
#  'DW Simpson Global Actuarial Recruitment']

# %%
def extract_location_from_result(soup): 
    locations = []
    spans = soup.findAll('span', attrs={'class': 'location'})
    for span in spans:
        locations.append(span.text)
    return(locations)

extract_location_from_result(soup)
# Out:
# ['Coraopolis, PA 15108',
#  'Township of Moon, PA 15108',
#  'Coraopolis, PA',
#  'Coraopolis, PA 15108']

# %%
def extract_salary_from_result(soup): 
    salaries = []
    for div in soup.find_all(name="div", attrs={"class":"row"}):
        try:
            salaries.append(div.find('nobr').text)
        except:
            try:
                div_two = div.find(name="div", attrs={"class":"sjcl"})
                div_three = div_two.find("div")
                salaries.append(div_three.text.strip())
            except:
                salaries.append("Nothing_found")
    return(salaries)

extract_salary_from_result(soup)
# Out:
# ['05 Ascensia Diabetes Care US Inc.',
#  'Liberty Lending',
#  'Quest Groups LLC',
#  'Chembio Diagnostic Systems, Inc.\n\n\n7 reviews',
#  'Bloomberg\n\n\n668 reviews',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Nothing_found',
#  'Church Pension Group\n\n\n23 reviews',
#  'Fora Financial LLC\n\n\n20 reviews']

# %%
def extract_summary_from_result(soup): 
    summaries = []
    spans = soup.findAll('span', attrs={'class': 'summary'})
    for span in spans:
        summaries.append(span.text.strip())
    return(summaries)

extract_summary_from_result(soup)
# Out:
# ['Experience in and understanding of data and information management, especially in Big Data trends. Responsibilities include analyses of various data streams,...',
#  'Data scientist to work as a statistician, data miner, and business analyst for the Risk Department. Conduct data mining from internal and external data sources....',
#  'Collaborate with data managers and engineers to specify requirements for data infrastructure and storage. My Pre IPO Client is looking for an experienced Data...',
#  'The Junior Scientist is responsible for performing experiments to develop and refine state-of-the-art assays for the detection of infectious diseases....',
#  'The infrastructure and algorithms we develop are used across the company by data scientists. To extract relevant, meaningful, tradable, and actionable...',
#  'R&D QA Scientist. Develops reference files, quality control charts, and graphs on laboratory data. Technical support may include plant support & data review etc...',
#  'Proficiency in using basic word processing and data management software is required. The mission is carried out in close collaboration with USDA-ARS and USDA...',
#  'The Property Valuation & Mapping Unit in the Department of Finance is seeking a Geospatial Data Scientist or Analyst to provide imagery and GIS processing,...',
#  "Minimum of 5 - 7 years' data management experience preferably within a data and database management team....",
#  'Able to understand various data structures and common methods in data transformation. We are looking for a Data Scientist that will help us discover the...',
#  '2+ years of experience with data profiling, data modeling, and data pipeline development. Prepare, clean, format analytical datasets for processing by data...',
#  'We have a client that is looking for a data scientist to add to its team. Call Center or Customer care data experience a plus....',
#  'You’ve worked as a Data Scientist analyzing complex data with SQL, Python, and/or R. We seek an extraordinary Data Scientist to join our Technology Platform...',
#  'We are seeking a razor sharp Data Scientist to blend our data into insights that will enable us to deliver healthy and convenient frozen foods to more and more...',
#  'Data Scientists to help manage image and raw data resources. We are looking for a curious and tech-savvy data scientist who is passionate about IoT devices and...',
#  'The Associate Data Scientist will work closely with Senior Data Scientist to mine data, analyze and model variety data using advanced statistical methods for...',
#  'A Day in the Life of a Data Scientist:. Identify new data sources/patterns that add significant lift to predictive modeling capabilities....']

# %%
max_results_per_city = 10
city_set = ['New+York','Chicago','San+Francisco', 'Austin', 'Seattle', 'Los+Angeles', 'Philadelphia', 'Atlanta', 'Dallas','Pittsburgh', 'Portland', 'Phoenix', 'Denver', 'Houston', 'Miami', 'Washington+DC', 'Boulder']
#city_set = ['Toronto']
columns = ["city", "job_title", "company_name", "location", "summary", "salary"]
sample_df = pd.DataFrame(columns = columns)

# %%
for city in city_set:
    for start in range(0, max_results_per_city, 10):
        page = requests.get('http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l=' + str(city) + '&start=' + str(start))
        print("page: " + str(start))
        time.sleep(1)  #ensuring at least 1 second between page grabs
        soup = BeautifulSoup(page.text, "lxml", from_encoding="utf-8")
        for div in soup.find_all(name="div", attrs={"class":"row"}): 
            #specifying row num for index of job posting in dataframe
            num = (len(sample_df) + 1) 
            #creating an empty list to hold the data for each posting
            job_post = [] 
            #append city name
            job_post.append(city)
            #print(city)
            
            #grab job title
            for a in div.find_all(name="a", attrs={"data-tn-element":"jobTitle"}):
                job_post.append(a["title"])
                
            #grabbing company name
            company = div.find_all(name="span", attrs={"class":"company"}) 
            if len(company) > 0: 
                for b in company:
                    job_post.append(b.text.strip()) 
            else: 
                sec_try = div.find_all(name="span", attrs={"class":"result-link-source"})
                for span in sec_try:
                    job_post.append(span.text)
                    
            #grabbing location name
            c = div.findAll('span', attrs={'class': 'location'})
            if len(c) > 0:
                for span in c: 
                    job_post.append(span.text)
            else:
                    job_post.append("Nothing_found")
            #grabbing summary text
            d = div.findAll('span', attrs={'class': 'summary'}) 
            for span in d:
                job_post.append(span.text.strip()) 
            #grabbing salary
            try:
                job_post.append(div.find('nobr').text) 
            except:
                try:
                    div_two = div.find(name="div", attrs={"class":"sjcl"}) 
                    div_three = div_two.find("div") 
                    job_post.append(div_three.text.strip())
                except:
                    job_post.append("Nothing_found")         
                    
            print("job post:")
            print(job_post)
            print("job post length:")
            print(len(job_post))
            sample_df.loc[num] = job_post   
          
        #sample_df.loc[num] = job_post        
#return sample_df
# Out:
# page: 0
# C:\Users\Larissa\Anaconda3\lib\site-packages\bs4\__init__.py:146: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# job post:
# ['New+York', 'Data Scientist', 'Fora Financial LLC', 'Nothing_found', 'A Day in the Life of a Data Scientist:. Identify new data sources/patterns that add significant lift to predictive modeling capabilities....', 'Fora Financial LLC\n\n\n20 reviews']
# job post length:
# 6
# job post:
# ['New+York', 'Data Scientist', 'Liberty Lending', 'Nothing_found', 'Data scientist to work as a statistician, data miner, and business analyst for the Risk Department. Conduct data mining from internal and external data sources....', 'Liberty Lending']
# job post length:
# 6
# job post:
# ['New+York', 'Quantitative Data Scientist', 'Harnham', 'Nothing_found', 'Quantatative Data Scientist. Their top priority is bringing on a strong Data Scientist to help grow their brand new team here in New York....', 'Harnham\n\n\n6 reviews']
# job post length:
# 6
# job post:
# ['New+York', 'AI Research Scientist', 'Bloomberg', 'Nothing_found', 'The infrastructure and algorithms we develop are used across the company by data scientists. To extract relevant, meaningful, tradable, and actionable...', 'Bloomberg\n\n\n670 reviews']
# job post length:
# 6
# job post:
# ['New+York', 'Data Scientist', 'SupplyHouse.com', 'Melville, NY', 'Discover new data points and validate existing data sources. SupplyHouse.com, an ecommerce heating, plumbing, and HVAC supply company is searching for a data...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Associate Data Scientist, Premium Analytics', 'Spotify', 'New York, NY 10011 (Chelsea area)', 'You will work with a global team of world-class analysts, data scientists, business managers, marketers, and engineers....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Data/NLP Scientist', 'Storm Global Analytics', 'New York, NY', 'Design NLP models for searching structured/unstructured data in real/near-real time. Good in designing language models (involves all steps of development - data...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Data Scientist Summer Intern', 'WeWork', 'New York, NY', 'Comfortable with quantitative analysis, statistical techniques, data mining. Use large, complex data sets to monitor office demand across different product...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Data Scientist, Intern (2019)', '1010data', 'New York, NY', '1010data is a highly differentiated product that is becoming the industry standard for Big Data Discovery and Data Sharing....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'ASSOCIATE DATA SCIENTIST', 'Foot Locker, Inc.', 'New York, NY', 'The Associate Data Scientist assists the team in developing predictive models, mining data sets for insights, ensuring the success of assigned projects, and...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Data Scientist Intern', 'Raindrop', 'New York, NY', 'Good communication skills, and experience telling stories with data. We aim to deliver a bridge-building experience that goes beyond the surface of judging...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Analyst | Data Analysis', 'New York City OFFICE OF MANAGEMENT & BUDGET', 'Manhattan, NY', 'Data AnalysisJOB TITLE:. Provide assistance to assess data to address research questions and provide the data feed to assist other groups with their research...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Competitions Programs Specialist, Talent Programs and Events', 'Google', 'New York, NY 10011 (Chelsea area)', 'Manage the ongoing reporting and data analysis including; Detailed tracking of metrics, thorough quantitative and qualitative analysis, development of...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Data Scientist', 'Rent the Runway', 'New York, NY', 'Mine the data ecosystem & find fruitful signals. Passion for data and its ability to drive serious business impact....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['New+York', 'Associate Data Scientist', 'Church Pension Group', 'Nothing_found', 'The Associate Data Scientist will work closely with Senior Data Scientist to mine data, analyze and model variety data using advanced statistical methods for...', 'Church Pension Group\n\n\n23 reviews']
# job post length:
# 6
# job post:
# ['New+York', 'R&D Scientist, Jr.', 'Chembio Diagnostic Systems, Inc.', 'Nothing_found', 'The Junior Scientist is responsible for performing experiments to develop and refine state-of-the-art assays for the detection of infectious diseases....', 'Chembio Diagnostic Systems, Inc.\n\n\n7 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Chicago', 'Arity - Data Scientist Intern', 'Allstate', 'Nothing_found', 'The Data Scientist family is accountable for using data to make decisions, which includes building predictive models and developing new machine learning...', 'Allstate\n\n\n5,668 reviews']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist', 'Crowe', 'Nothing_found', 'Collaborate with analytic and data teams to set objectives, approaches, and work plans. Leverage large sets of structured and unstructured data to develop...', 'Crowe\n\n\n183 reviews']
# job post length:
# 6
# job post:
# ['Chicago', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Analyst - Entry-Level - Technology Startup', 'Enterprise Peak', 'Chicago, IL', 'Data Analyst Responsibilities:. The Data Analyst will join our data engineering team and will be responsible for mapping out high-tech labor markets....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist', 'Civis Analytics', 'Chicago, IL', 'Experience working with imperfect data. At Civis, our data scientists contribute to our core research goals of developing new methodological approaches to the...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Junior Variant Scientist', 'Tempus', 'Chicago, IL', "We now have more data than ever before, but providers don't have the infrastructure or expertise to make sense of this data....", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Decision Scientist', 'Resource Systems Group Inc.', 'Chicago, IL 60601 (Loop area)', 'Data Visualization experience. AS A DECISION SCIENTIST. Proficient in statistical analysis, data management and presentation....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist Intern', 'Brookfield Asset Management', 'Chicago, IL', 'Data Scientist Intern. Help the team automate a variety of analytic and data driven tasks. Find patterns and insights in unstructured data as it relates to real...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Jr. Clinical Trials Data Specialist', 'Tempus', 'Chicago, IL 60654 (Loop area)', "We now have more data than ever before, but providers don't have the infrastructure or expertise to make sense of this data....", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Staff Scientist', 'The University of Chicago', 'Chicago, IL', 'A Staff Scientist is responsible for all aspects of research projects and research facilities. The individual will assist users in image processing and other...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Health Care Data Analyst', 'NORC at the University of Chicago', 'Chicago, IL', 'At NORC, Data Analysts work with our Data Scientists, and play a strategic role in supporting our research teams to produce valuable insights for our clients....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist - Life Sciences', 'Argonne National Laboratory', 'Lemont, IL', 'Problems typically involve the construction of computational models for phenotype prediction from data that includes genomic data and other omics data....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist', 'Wunderman', 'Chicago, IL', 'Support Lead Data Scientist in delivering a wider range of data science projects predominantly using python & cloud-based services. About Wunderman Data....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Chicago', 'Data Scientist (944)', 'ABC Supply Co. Inc', 'Nothing_found', 'Collaborate on data collection efforts (external API’s, public data sources, etc.). We are aiming to transform our business with data science, and as a Data...', 'ABC Supply Co. Inc\n\n\n456 reviews']
# job post length:
# 6
# job post:
# ['Chicago', 'Senior Data Scientist', 'Trunk Club', 'Nothing_found', 'Data Science helps drive Trunk Club. Proven track record working hands-on with data end-to-end. Demonstrated success visualizing data and explaining complex...', 'Trunk Club\n\n\n93 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['San+Francisco', 'Data Visualization Engineer', 'eBay Inc.', 'Nothing_found', 'Collaborate with data scientists, analysts, and data engineers to translate business questions into flexible tools and dashboards that scale across the...', 'eBay Inc.\n\n\n1,530 reviews']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Senior Data Scientist', 'OpenTable', 'Nothing_found', 'Senior Data Scientist. 3+ years of industry experience as a Data Scientist or equivalent. Experience with data exploration and analysis....', 'OpenTable\n\n\n35 reviews']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist - Insurance', 'Blue Owl', 'Nothing_found', 'This role will require the candidate to be extremely hands on with building models and data driven tools. We invite you to help us build an InsurTech company...', 'Blue Owl']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Associate Scientist /Scientist, DMPK', 'Genentech', 'Nothing_found', 'DMPK data analysis and modeling. Collaboration with scientists within and outside DMPK to support projects....', 'Genentech\n\n\n726 reviews']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist / Machine Learning Engineer - Classification Science', 'Rakuten Intelligence', 'Nothing_found', 'Rakuten Intelligence is looking for a Data Scientist / Machine Learning Engineer to join our Classification Science team....', 'Rakuten Intelligence']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist - Quip', 'Salesforce', 'San Francisco, CA', "We're looking for a Data Scientist who can surface actionable insights that transform our product. As a Data Scientist at Quip, you'll partner with cross...", 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Junior Data Analyst', 'ThirdLove', 'San Francisco, CA', 'Partner with data scientists, data engineers and analysts to validate accuracy and cleanliness of data. Use SQL to pull data from the database for analysis....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Journalist', 'Mother Jones', 'San Francisco, CA 94108 (Financial District area)', 'You might be a journalist with a solid data-science background or a data scientist with journalism experience....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist Consultant', 'VirtusaPolaris Software Services', 'San Francisco, CA', 'Data Scientist /R Language:. Need someone from Data Science Background. Good knowledge of R Language....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist or Data Analyst', 'Autodesk', 'San Francisco, CA', 'Data Scientist or Data Analyst. You love learning, data, scale and agility. Ability to navigate through various systems and data pools....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist', 'University of California San Francisco', 'San Francisco, CA 94104 (Financial District area)', 'The Data Scientist will work closely with Brain Tumor Center investigators and data scientists at the Institute for Computational Health Sciences to...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Competitions Programs Specialist, Talent Programs and Events', 'Google', 'San Francisco, CA', 'Manage the ongoing reporting and data analysis including; Detailed tracking of metrics, thorough quantitative and qualitative analysis, development of...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Clinical Data Operator', 'Natera', 'San Carlos, CA 94070', 'Previous data entry experience is preferred. Accurately enter patient data into the Laboratory Inventory Management System (LIMS)....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Policy & Research Analyst', 'United States District Court', 'San Francisco, CA', 'Announcement Number: 18-10 Court: Office of the Circuit Executive Ninth Circuit City, State: San Francisco, CA Court Website: https://www.ca9.uscourts.gov/...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Analyst / Scientist [Full-time or intern)]', 'Plato HQ', 'San Francisco, CA', 'As our first Data Analyst / Scientist, you’ll be very autonomous and build this team from scratch. A data nerd - you are highly confortable with basic languages...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist', 'Grand Rounds', 'Nothing_found', 'Work closely with analysts, data scientists, product managers, and engineers. Learn about on-going initiatives involving data scientists, product managers, and...', 'Grand Rounds\n\n\n11 reviews']
# job post length:
# 6
# job post:
# ['San+Francisco', 'Data Scientist, Product analytics', 'eBay Inc.', 'Nothing_found', 'Data Scientist, Product Analytics. We are looking for an experienced Data scientist with exceptional product sense to help champion the use of data in product...', 'eBay Inc.\n\n\n1,530 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Austin', 'Data Scientist / Predictive Modeler', 'M Theory Solutions', 'Nothing_found', 'Ready to demonstrate your marketing analytics and data sciences prowess? You’ll have access to large B2B and B2C data sets on a robust analytic platform....', 'M Theory Solutions']
# job post length:
# 6
# job post:
# ['Austin', 'Product Scientist', 'Indeed', 'Nothing_found', "Work alongside other data scientists and software engineers to expand Indeed's catalog of tools, techniques, and best practices for manipulating and...", 'Indeed\n\n\n359 reviews']
# job post length:
# 6
# job post:
# ['Austin', 'Data Science Leader', 'Indeed', 'Nothing_found', 'Our Data Scientists build and implement machine learning models to make timely decisions. The role of Data Science at Indeed is to follow the data....', 'Indeed\n\n\n359 reviews']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Austin', 'Director of Engineering: Big Data AI', 'Dau International LLC', 'Nothing_found', '16 direct reports across two teams (2 Architects, 3 Data Scientists, 11 Engineers). Further recruit and develop software engineering talent, Data science talent...', 'Dau International LLC']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist - Own All Our Big Data Initiatives', 'Alamo Drafthouse Cinemas', 'Austin, TX 78701 (Downtown area)', 'Why Does Alamo Drafthouse Need a Data Scientist? Expertise in schema design and developing data models for complex data sets....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Associate Research Scientist', 'Senseye', 'Austin, TX', 'You will work closely with our Research Scientists and Data Scientists, and will be involved in all aspects of our studies, including literature review,...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist and Cognitive Engineer, Entry-Level', 'State Street', 'Austin, TX 78701 (Downtown area)', 'Perform data collection, preprocessing, feature engineering, data visualization and analysis. Work with a team of data scientists, machine learning engineers,...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Scientist I', 'Sonic Healthcare USA', 'Austin, TX', 'Processes data following SRL procedures and guidelines. The Scientist I is responsible for performing routine sample analysis, LCMS and/or ICPMS analytical...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist', 'DELL', 'Round Rock, TX 78664', 'GCCO is seeking a Data Scientist who will be able to envision and create data science models in support of business operations....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist', 'Advantine Technologies', 'Austin, TX', 'Experience using statistical computer languages (R, Python, SAS) to manipulate data and draw insights from large data sets....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Staff Scientist - Round Rock', 'Golder Associates', 'Round Rock, TX', 'Staff Scientist - Round Rock. Collecting and managing field and analytical data from investigations. We are seeking to hire a Staff Scientist for Texas...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Research Engineering/ Scientist Associate I', 'University of Texas at Austin', 'Austin, TX', 'Purpose To perform entry-level engineering and/or scientific assignments related to gene cloning and expression analysis, mutagenesis, and protein purification...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist / Predictive Modeler', 'M Theory Solutions', 'Austin, TX 78728', 'Ready to demonstrate your marketing analytics and data sciences prowess? You’ll have access to large B2B and B2C data sets on a robust analytic platform....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist', 'Shipwell', 'Austin, TX 78701 (Downtown area)', 'The Data Scientist role provides you with a unique opportunity to join a high growth, third-party logistics company as we pivot into a record-breaking 3rd year....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Austin', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Austin', 'Data Scientist', 'eBay Inc.', 'Nothing_found', 'We are looking for a highly talented and self-motivated data scientist to join our Decision Science team. The data scientist will support the risk department,...', 'eBay Inc.\n\n\n1,530 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Seattle', 'D3 - Data Science Intern (Bothell)', 'Allstate', 'Nothing_found', 'The Data Scientist Family requires Analytic Agility, the ability to quickly learn new modeling/machine learning techniques, programming languages, and see how...', 'Allstate\n\n\n5,668 reviews']
# job post length:
# 6
# job post:
# ['Seattle', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Seattle', 'Research & Data Analyst (Long Term Temporary)', 'King County Housing Authority', 'Nothing_found', 'Preparation of data extracts and matched data sets; Participation in qualitative and/or quantitative data collection and management processes including tool...', 'King County Housing Authority\n\n\n14 reviews']
# job post length:
# 6
# job post:
# ['Seattle', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Seattle', 'Clinical Data Coordinator', 'Axio Research LLC', 'Seattle, WA 98121 (Belltown area)', 'Axio Research is seeking an entry level Data Coordinator to be a part of our growing data management team responsible for processing the data flow for multiple...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'DATA ENTRY OPERATOR', 'University of Washington', 'Seattle, WA', 'Major Responsibilities of the Data Entry Operator include:. The Contact Center has an outstanding opportunity for a Full-Time Data Entry Operator....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Associate Data Scientist I', 'PeopleMaven', 'Seattle, WA', 'We are looking for a Data Scientist that will help us discover the information hidden in vast amounts of data, and help us make smarter decisions to deliver...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Entry Level Office Administrator', 'BOEING', 'Tukwila, WA', "Skilled scientists and thinkers. Collects and compiles data to provide visibility of status for traveler's review and/or signature....", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Senior Data Journalist', 'Textio', 'Seattle, WA 98104 (First Hill area)', 'Work with language data sets and turn data insights into compelling narratives. Your work speaks not only to data scientists and linguists, but to anyone....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Specialist, Intern Programs', 'Google', 'Seattle, WA', 'Define, measure and prove ROI to clients using data analysis. Collaborate with the team on potential recommendations/insights based on the data and projections....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Data Scientist 2', 'Beyondsoft Consulting', 'Redmond, WA', 'You will collaborate closely with data scientists, program managers and other engineers to wallow in data leading to new insights and business intelligence....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Office Administrator', 'BOEING', 'Everett, WA 98204 (Holly area)', "Skilled scientists and thinkers. Collects and compiles data to provide visibility of status for traveler's review and/or signature....", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Data Scientist Intern, Summer 2019', 'Groupon', 'Seattle, WA 98101 (Downtown area)', 'We develop and use ground-breaking data technologies and data science algorithms to sift through large amounts of data and distill it into information about our...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'CONTACT CENTER REPRESENTATIVE 2', 'University of Washington', 'Seattle, WA', 'Observes principles of data security and patient confidentiality. The mission of UW Medicine is to improve the health of the public by advancing medical...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Seattle', 'Principal Data Scientist', 'Big Fish Games', 'Nothing_found', 'Mentor junior data analysts and data scientists. Lead or collaborate with a team of data scientists, game data analysts or big data engineers on analytical...', 'Big Fish Games\n\n\n19 reviews']
# job post length:
# 6
# job post:
# ['Seattle', 'Data Scientist 2', 'eXcell', 'Nothing_found', 'The Data Scientist will take data driven decisions through Experimentation. You will collaborate closely with data scientists, program managers and other...', 'eXcell\n\n\n78 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Los+Angeles', 'Associate Data Scientist', 'DISNEY', 'Nothing_found', 'In this role, you will be responsible for driving improvements across DTCI’s portfolio of offerings by using data....', 'DISNEY\n\n\n4,329 reviews']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Research Analyst', 'The Claro Group', 'Nothing_found', 'Technical data analysis. Data collection and database construction. Share findings with key stakeholders and our data analysis community by documenting and...', 'The Claro Group']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Project Scientist (Immunology)', 'Cedars-Sinai', 'Nothing_found', 'Analyzes, interprets, summarizes and compiles data. Project Scientists are not required to carry out independent research or to develop an independent research...', 'Cedars-Sinai\n\n\n703 reviews']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'NASA JPL Internship: Machine learning and remote sensing data fusion', 'NASA Jet Propulsion Laboratory', 'Pasadena, CA', 'Machine learning and remote sensing data fusion*. This project seeks to implement advanced data analytics and machine learning techniques to extract and...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Scientist (Entry Level)', 'HIRECLOUT', 'Los Angeles, CA', 'Data Scientist (Entry Level). Our client is seeking an Entry Level Data Scientist to participate in activities across the data science lifecycle:....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Researcher', 'Riot Games', 'Los Angeles, CA 90064', "As a Researcher, you'll join the Insights discipline – the group of researchers, analysts, data scientists, and strategists responsible for solving problems and...", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Scientist', 'TVG Network Betfair US', 'Los Angeles, CA', 'Develop custom data models and algorithms to apply to data sets. Assess the effectiveness and accuracy of new data sources and data gathering techniques....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Scientist', 'PatientPop', 'Santa Monica, CA 90401', 'But all of this is meaningless without great people, so we are looking for a Data Scientist to help us build a world-class data science and analytics practice....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Scientist', 'Tradesy', 'Santa Monica, CA 90401', 'Experience with Hadoop and/or other data processing platforms based on Hadoop. Use historical data to identify market trends, predict supply and demand, and...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Lab I Assoc', 'Quest Diagnostics', 'West Hills, CA 91307', "Performs data entry or transfers data to computer for data reduction and prepares for clinical laboratory scientist's review....", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Scientist', 'Rouse Services', 'Beverly Hills, CA 90211', 'ETL, data processing, data architecture, and/or database programming. The Data Scientist will be charged with advancing Rouse’s proprietary valuation model....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Cancer Registry Abstract Clerk', 'Kaiser Permanente', 'Pasadena, CA', 'Accurate information is essential for successful use of the data by Kaiser Physicians, research scientists and external public health agencies....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Office Manager', 'STRIVR', 'Los Angeles, CA', 'The STRIVR team includes industry leaders that have been studying and building VR for 20+ years, data scientists, instructional designers, and former pro...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Los+Angeles', 'Data Research Analyst', 'Lease Advisors', 'Nothing_found', 'Research and data analysis. As we continue to grow into a global business Lease Advisors is looking for people to support our research and data entry efforts....', 'Lease Advisors\n\n\n2 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Philadelphia', 'Senior Data Scientist', 'Subaru of America', 'Nothing_found', 'Implements this strategy by reviewing our various data sets to understand data trends. Ability to use advanced techniques to handle big data with structured and...', 'Subaru of America\n\n\n145 reviews']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Data Scientist - Conshohocken, PA', 'RS Energy Group', 'Nothing_found', 'Work together with Data Engineers and Software Developers to evaluate the technical trade-offs of tools to build simple, yet robust, data science pipelines....', 'RS Energy Group']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Data Scientist', 'EcoMetric', 'Philadelphia, PA', 'EcoMetric Consulting is looking for a data scientist to join our team in the Greater Philadelphia or Denver areas....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Associate Scientist, TEM', 'Wuxi AppTec', 'Philadelphia, PA', 'Ability to record data accurately and legibly. Correctly analyzes scientific data with accuracy and precision....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Data Scientist', 'Life Cycle Engineering', 'Philadelphia, PA 19112 (Marconi Plaza-Packer Park area)', 'As a Data Scientist, you will assist with the design, development, testing, and data manipulation of software to satisfy system/subsystems functional...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Staff Scientist 1', 'City of Philadelphia', 'Philadelphia, PA', 'Environmental Scientist Specialist (3H16). Laboratory Program Scientist (3H18) (Chemistry Specialty Only). Employees provide technical guidance, review, and may...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Temporary Data Analyst (Institutional Research)', 'University of the Sciences in Philadelphia', 'Philadelphia, PA 19104 (Belmont area)', 'The Temporary Data Analyst will review data for quality and accuracy for external and internal reporting, distilling from Excel file sources, utilizing Pivot...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Forensic Scientist', 'Quest Diagnostics', 'Norristown, PA', 'Of equipment utilized in area of responsibility, capable of programming sequence table for sample analysis, capable of basic data review....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Assistant Scientist', 'Temple University', 'Philadelphia, PA', 'Maintaining records of data; The Assistant Scientist will be preparing necessary related reagents for gene therapy vector production;...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Junior Versatile Technologist', 'BOEING', 'Ridley Park, PA', 'Skilled scientists and thinkers. Experience with performing analysis utilizing aircraft, maintenance, supply, and other logistical data....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Data Analyst / Data Scientist', 'Defined Clarity', 'Philadelphia, PA 19123 (Poplar-Ludlow-Yorktowne area)', 'We have a client that is looking for a data scientist to add to its team. Call Center or Customer care data experience a plus....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Data Scientist', 'Drexel University', 'Philadelphia, PA', "Experience building and optimizing 'big data' data platforms, architectures and data sets. The position will be involved in developing data collection and data...", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Software Engineer (Data Science Team) - Conshohocken, PA', 'RS Energy Group', 'Nothing_found', 'Solid understanding of algorithms and data structures. Collaborate with Data Scientists and the rest of the software engineering team to design, test and launch...', 'RS Energy Group']
# job post length:
# 6
# job post:
# ['Philadelphia', 'Senior Data Scientist', 'Elite SEM', 'Nothing_found', 'Lead analytical projects by leveraging and coaching Jr Data Scientists. As the Senior Data Scientist you will help us discover the information hidden in vast...', 'Elite SEM']
# job post length:
# 6
# page: 0
# job post:
# ['Atlanta', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist', 'HUNTER Technical Resources', 'Nothing_found', 'Data Scientist Required Skills & Experience: Experience applying statistics to business contexts. A strong candidate will have previously delivered a wide...', 'HUNTER Technical Resources\n\n\n6 reviews']
# job post length:
# 6
# job post:
# ['Atlanta', 'Scientist - Chemical Characterization', 'Alcon', 'Nothing_found', 'Technical scientific writing and data presentation, including basic statistical analysis of data....', 'Alcon\n\n\n1,022 reviews']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist', 'Westrock', 'Nothing_found', 'Associate Data Scientist*. Builds large data sets from multiple sources to build algorithms for predicting future data characteristics....', 'Westrock']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist || Atlanta, GA || 12+months || Phone then Face to Face', 'Infogium Technologies LLC', 'Atlanta, GA', 'Data Scientist role is changing to a Full Stack AI developer…. Phone then Face to Face*....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist/Machine Learning Trainee', 'Norfolk Southern Corp', 'Atlanta, GA 30309 (Midtown area)', 'You will have the opportunity of working with Norfolk Southern’s big data analytics platform and mine massive amounts of data using various toolsets like R,...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Health Scientist', 'CDC', 'Atlanta, GA 30341', 'Data Analysis and Interpretation. Specialized experience is experience at or equivalent to which is directly related to the position which has equipped the...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Flight Safety Data Analysis Spring 2019 Co-Op', 'Delta TechOps', 'Atlanta, GA 30354 (Lakewood Heights-Southeastern area)', 'The successful candidate will be responsible for collecting factual data, such as damage data, injury information, meteorological conditions, crew background,...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Forensic Scientist', 'Quest Diagnostics', 'Tucker, GA', 'Of equipment utilized in area of responsibility, capable of programming sequence table for sample analysis, capable of basic data review....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist opportunity in Atlanta', 'Zensar Technologies', 'Atlanta, GA 30308 (Old Fourth Ward area)', 'Performs sophisticated data analytics (encompassing data mining, inferential statistical analysis, and predictive analytics, for example)....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist', 'Ace Technologies', 'Atlanta, GA', 'Data Scientist role is changing to a Full Stack AI developer…. JAVA script CSS python....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Entry-Level Natural Resource Scientist', 'Wood', 'Kennesaw, GA', 'Acts as a data gatherer; Wood Environment & Infrastructure Solutions is seeking an Entry - Level Natural Resource Scientist to join our Kennesaw (Atlanta),...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Entry to Junior-Level Environmental Scientist', 'Wood', 'Kennesaw, GA', 'Field exploration, inspection, data collection analysis, and interpretation. Wood is currently seeking an Entry to Junior-level Environmental Scientist to join...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Junior Environmental Scientist', 'CALYX Engineers + Consultants', 'Roswell, GA 30075', 'Conduct ecology field investigations and data collection. Writing skills and ability to interpret and present field data in technical reports....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Atlanta', 'Field Application Scientist', 'Sartorius North America', 'Nothing_found', 'Essen BioScience enables scientists and researchers to better understand live-cell behaviors and functions, and conduct live-cell experiments more efficiently...', 'Sartorius North America']
# job post length:
# 6
# job post:
# ['Atlanta', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# page: 0
# job post:
# ['Dallas', 'Data Scientist - Immediate need', 'MNR IT Solutions LLC', 'Nothing_found', 'Implements statistical data quality procedures on new data sources, and by applying rigorous iterative data analytics, supports Data Scientists in data sourcing...', 'MNR IT Solutions LLC']
# job post length:
# 6
# job post:
# ['Dallas', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Dallas', 'Senior Scientist/Scientist', 'Reata Pharmaceuticals, Inc.', 'Nothing_found', 'Reviewing, analyzing, and interpreting scientific data and results; Collaborating with other scientists and keeping current with field of expertise, including...', 'Reata Pharmaceuticals, Inc.']
# job post length:
# 6
# job post:
# ['Dallas', 'Machine Learning Engineer - Mid Level', 'USAA', 'Nothing_found', 'Purpose of Job We are currently seeking a talented Machine Learning Engineer - Mid Level for our Plano, TX facility. Machine Learning Engineers are engaged...', 'USAA\n\n\n2,171 reviews']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist and Platform Developer', 'Citi', 'Nothing_found', 'Able to define the correct data, analyze and interpret data leveraging complex data models and noisy data sources....', 'Citi\n\n\n14,625 reviews']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist-Tchnlgy', 'Walmart', 'Plano, TX 75086', 'Presents data insights and recommendations to key stakeholders. Certificate in business analytics, data mining, or statistical analysis....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist', 'Proximate Technologies Inc.', 'Plano, TX 75093', 'Strong understanding of experimental design, hypothesis testing, and pitfalls of interpreting observational data....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist', 'Money Mart Financial Services', 'Dallas, TX 75224 (Southwest Dallas area)', 'Job Description What do we need? You to have an amazing personality and communication style. That you are super-organized and are a problem solver. That you...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Chief Data Scientist', 'Commerx', 'Plano, TX', 'SaaS, PaaS offerings SDN, NFV concepts Cloud Security implementation Cloud Orchestration Analytics and using this data to dimension/expand/plan cloud resources...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist I', 'Federal Reserve Bank of Dallas', 'Dallas, TX', 'Data Scientist I-256793. The HR Data Scientist I will provide the department and the organization with support in analyzing and presenting data using...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist: Applied Machine Learning and Advertising Modeling', 'AT&T', 'Plano, TX', 'Senior Data Scientist. A strong understanding of advertisingand media data sets, machine learning and deep learning model development aswell as data product...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Marketing Data Scientist', 'Funnel Science', 'Plano, TX 75075', 'Marketing Data Scientist. Under supervision of our CTO, directly modeling client data. To apply, send a resume and cover note in an email with the role for...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist, Forecasting & Planning', "Fred's", 'Dallas, TX', 'The Data Scientist will create practical methods to forecast demand, understand customer preferences, analyze demand elasticity, and optimize data to inform...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist', 'Dollar Financial Group', 'Dallas, TX', 'Job Description DUTIES/RESPONSIBILITIES Develop marketing, credit risk models, segmentation, and risk analytics Perform all required tests and measures of...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data & Applied Scientist- PCCI', 'Parkland Health and Hospital System', 'Dallas, TX', 'Data & Applied Scientist- PCCI. Seeks to use all of the above methods to find and interpret data sources, manage the data, and ensure consistency of data-sets,...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Dallas', 'Data Science Instructor', 'Thinkful', 'Nothing_found', '3+ years experience as a data scientist, including Python experience. You’ll lead technical workshops teaching the basics of data science, primarily focusing on...', 'Thinkful']
# job post length:
# 6
# page: 0
# job post:
# ['Pittsburgh', 'Data Scientist I/II', 'U. S. Steel', 'Nothing_found', 'Steel has an immediate opening for a Data Scientist. Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment....', 'U. S. Steel']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Manufacturing Technician', 'nanoGriptech, Inc.', 'Nothing_found', 'Compile data and write summaries on computer. Maintain and enter data accurately into multiple software programs to organize, analyze and record work....', 'nanoGriptech, Inc.']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Associate Scientist – Polyurethane Rigid Insulating Foam Applications Development', 'Covestro', 'Nothing_found', 'As an Associate Scientist, you will lead and support the development of Polyurethane Rigid Insulating Foam applications to support our business strategy....', 'Covestro\n\n\n46 reviews']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Artificial Intelligence Programmer/Machine learning Developer', 'Computer Enterprises, Inc. (CEI)', 'Nothing_found', 'POSITION SUMMARY: Individual should be experienced in CT medical imaging algorithmwith experience in conventional image processing, Deep Learning and CNN...', 'Computer Enterprises, Inc. (CEI)\n\n\n14 reviews']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Statistical Data Analyst', 'The University of Pittsburgh', 'Pittsburgh, PA', 'The Statistical Data Analyst will work at the Center for Research Healthcare Data Center, which supports University researchers by providing expert consultation...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Scientist I', 'The Pittsburgh Water and Sewer Authority', 'Pittsburgh, PA', 'Scientist I POSTED:. The Scientist I position shall perform moderately complex Scientist functions for various environmental or utilities projects....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Data Scientist', 'UPMC', 'Pittsburgh, PA 15219 (Middle Hill area)', 'UPMC Community Care Behavioral Health is seeking a Data Scientist for its downtown Pittsburgh location at the U.S....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Data Scientist', 'The University of Pittsburgh', 'Pittsburgh, PA', 'The Data Scientist will work to improve existing data management systems, provide reporting support, and conduct analyses....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'SaaS Marketing Manager, Data Scientist', 'MSA, The Safety Company', 'Cranberry Township, PA 16066', 'Provide data driven recommendations to both internal and external customers regarding their data sets. Collaborate with internal resources to customize data...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Data Scientist', 'PNC Financial Services Group', 'Pittsburgh, PA 15289 (Central Business District area)', 'Participates in the data gathering, data processing and data mining of large and complex datasets. May partner with Data Architects, Data Analysts, Data...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Associate Data Scientist - (Predictive Analytics)', 'Highmark Health', 'Pittsburgh, PA 15222 (Strip District area)', "Assemble the data set using knowledge of where the required data exist within Organization's source data system, derived production sets or publicly available...", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'DATA SCIENTIST / MACHINE LEARNING ENGINEER', 'Aspinity', 'Pittsburgh, PA', 'Aspinity is looking for an experienced data scientist to support optimization of algorithms and architectures for Aspinity’s revolutionary analog processor...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Associate Data Scientist', 'Highmark Health', 'Pittsburgh, PA 15222 (Strip District area)', "Assemble the data set using knowledge of where the required data exist within Organization's source data system, derived production sets or publicly available...", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Bioinformatics Research Scientist', 'Cognition Therapeutics', 'Nothing_found', 'Bioinformatics Research Scientist. Responsibilities include supervising collaborator and leading internal efforts to analyze large protein data sets, available...', 'Cognition Therapeutics']
# job post length:
# 6
# job post:
# ['Pittsburgh', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# page: 0
# job post:
# ['Portland', 'Data Scientist / Predictive Modeler', 'M Theory Solutions', 'Nothing_found', 'Ready to demonstrate your marketing analytics and data sciences prowess? You’ll have access to large B2B and B2C data sets on a robust analytic platform....', 'M Theory Solutions']
# job post length:
# 6
# job post:
# ...
# job post length:
# 6
# job post:
# ['Houston', 'Data Scientist, Revenue Management', 'Sysco', 'Nothing_found', 'Data acquisition, cleansing and manipulation; Perform data mining, cleansing, and manipulation; 3+ years of experience accessing and manipulating data in SQL or...', 'Sysco\n\n\n2,631 reviews']
# job post length:
# 6
# job post:
# ['Houston', 'Quantitative Research Scientist', 'NRG Energy', 'Nothing_found', 'Modeling and inference with panel data and time series data. We are currently looking to hire a Quantitative Research Scientist in our Retail Data Analytics...', 'NRG Energy\n\n\n319 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Miami', 'Data Scientist', 'TracFone Wireless', 'Nothing_found', 'The candidate will be required to clarify business requirements for new initiatives and interface with the users, external and internal support teams to...', 'TracFone Wireless\n\n\n91 reviews']
# job post length:
# 6
# job post:
# ['Miami', 'Data Science Instructor', 'Thinkful', 'Nothing_found', 'You’ll engage with attendees in-person on a weekly basis, and occasionally reply to emails or direct them to the appropriate Thinkful department.', 'Thinkful']
# job post length:
# 6
# job post:
# ['Miami', 'Open Source Analyst', 'Leidos', 'Nothing_found', 'Conduct strategic, tactical, and operational analysis of various publicly available data sources and unconventional deep and dark web sources with the...', 'Leidos\n\n\n653 reviews']
# job post length:
# 6
# job post:
# ['Miami', 'Data Scientist- Predictive', 'Focus Global Talent Solutions', 'Nothing_found', 'This individual will work with a multidisciplinary team of driven people to deliver end to end solutions that improve guest experience and address pain...', 'Focus Global Talent Solutions']
# job post length:
# 6
# job post:
# ['Miami', 'Data Scientist - Full Time', 'Miami HEAT', 'Miami, FL 33132 (Downtown area)', 'This position is responsible for conducting data science aimed at creating inferential and predictive models that reveal actionable business insights that...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Scientist-Microbiology (Entry Level)', 'Cardinal Health', 'Miami, FL 33155', 'General knowledge of the various microbiology laboratory and environment monitoring testing procedures, including bioburden, endotoxin testing, sterility...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Quality Assurance Scientist II', 'Beckman Coulter - Diagnostics', 'Miami, FL', 'Receive and process complaints escalated from internal and external customers related to products manufactured and or distributed and serviced by the company...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Material Handler', 'Beckman Coulter - Diagnostics', 'Miami, FL', 'The candidate must be able to load and unload materials, replenish raw materials in the plant, inspect FG material prior to shipment; create shipping...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Data Scientist - Remote', 'Adaxa Technologies', 'Fort Lauderdale, FL', 'Data acquisition and integration, including querying relational databases and developing ETL processes (including automated ETL processes), for medical or...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'BIOLOGICAL SCIENTIST II - SES - 64006908', 'The State of Florida', 'Fort Lauderdale, FL 33315 (River Oaks area)', 'Conducts field investigations in accordance with current STD Program Policy to locate and provide Direct Observe Therapy (DOT) to individuals infected with...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Data Scientist', 'TracFone Wireless', 'Miami, FL', 'The candidate will be required to clarify business requirements for new initiatives and interface with the users, external and internal support teams to...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Customer Facing Data Scientist', 'DataRobot', 'Miami, FL', 'You will need to be comfortable leading technical demonstrations of DataRobot, helping clients develop models that add value to their organizations, and...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'MEDICAL LABORATORY SCIENTIST I - 64067592', 'The State of Florida', 'Miami, FL 33125 (Flagami area)', 'Candidates claiming Veterans’ Preference must attach supporting documentation with each submission that includes character of service (for example, DD Form...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Data Scientist', 'BOXY CHARM', 'Miami, FL 33172', '* Collaborate closely with the Software Development and DevOps teams to ensure continued delivery of high quality data through our data processing pipeline', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Miami', 'Data Scientist, Ecommerce', 'Boxy Charm', 'Nothing_found', '* Collaborate closely with the Software Development and DevOps teams to ensure continued delivery of high quality data through our data processing pipeline', 'Boxy Charm\n\n\n6 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Washington+DC', 'Data Scientist', 'Central Intelligence Agency', 'Nothing_found', 'As a Data Scientist for the CIA, you will organize and interpret data to inform US decision makers, drive successful operations and shape CIA technology and...', 'Central Intelligence Agency\n\n\n158 reviews']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Mid-Level Data Scientist', 'ASR Analytics, LLC', 'Nothing_found', 'ASR has an immediate need for Data Scientists in the Washington, DC area. 2+ years using data mining methods, such as clustering and anomaly detection, to...', 'ASR Analytics, LLC']
# job post length:
# 6
# job post:
# ['Washington+DC', 'HP032 Data Technician', 'ADNET Systems, Inc.', 'Nothing_found', "HP032 Junior Data Technician, Part Time. We are seeking a Junior Data Technician to support the Solar Data Analysis Center (SDAC) at NASA's Goddard Space Flight...", 'ADNET Systems, Inc.\n\n\n9 reviews']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Analytic Consultant (Multiple Positions and Multiple Levels)', 'ASR Analytics, LLC', 'Nothing_found', 'ASR has an immediate need for Analytic Consultants and Data Scientists in the Washington, DC area. Experience working with a variety of data types (e.g.,...', 'ASR Analytics, LLC']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Lead Data Scientist', 'ASR Analytics, LLC', 'Nothing_found', 'ASR has an immediate need for Data Scientists in the Washington, DC area. Mongo, Neo4j) databases and data structures....', 'ASR Analytics, LLC']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Data Scientist - Entry to Experienced Level', 'National Security Agency', 'Nothing_found', 'Data Scientists are hired into positions directly supporting a technical mission office or the Data Scientist Development Program (DSDP)....', 'National Security Agency\n\n\n173 reviews']
# job post length:
# 6
# job post:
# ['Washington+DC', 'RESEARCH & DATA ANALYSIS INTERN', 'Luntz Global Partners', 'Washington, DC 20005 (Logan Circle area)', 'Assist with quantitative data report creation and in broader data analysis; Responsibility for proofing numerical data for accuracy....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Student Fellow', 'Transparency and Accountability Initiative', 'Washington, DC', 'Building on successes to date, which include playing a key role in the establishment and implementation of the Open Government Partnership and helping bridge...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Health Scientist (Informatics)', 'CDC', 'Hyattsville, MD', 'As a Health Scientist (Informatics) you will:. Skill in applying public health informatics to problems in data collection analysis and use....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Graduate Studies Program - Data Scientist', 'Central Intelligence Agency', 'Washington, DC', 'As a Data Scientist Graduate Intern for the CIA, you will work side-by-side with other Data Scientists to organize and interpret data to inform US decision...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'INFORMS Data Job Opportunities', 'Institute for Defense Analyses', 'Alexandria, VA', 'We are seeking data scientists to support the dynamic questions we receive from our government sponsors on a variety of topics....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Data Scientist', 'Booz Allen Hamilton', 'Washington, DC', 'As a data scientist, you can turn these complex data sets into useful information to solve global challenges. A chance to change the world with the Data Science...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Data Scientist', 'Elder Research Inc', 'Arlington, VA 22201 (Lyon Village area)', 'While we do not have any openings for Data Scientists at this time, you are welcome to submit a resume for our files....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Associate/Scientist', 'Exponent', 'Bowie, MD', 'Our multidisciplinary team of scientists, engineers, physicians, and regulatory consultants brings together more than 90 different disciplines to solve...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'HP032 Data Technician', 'ADNET Systems, Inc.', 'Greenbelt, MD 20771', "HP032 Junior Data Technician, Part Time. We are seeking a Junior Data Technician to support the Solar Data Analysis Center (SDAC) at NASA's Goddard Space Flight...", 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Research Analyst', 'Jacob’s Eye', 'Washington, DC', 'Providing suitable data to determine whether the ANG has brand awareness. As the Research Analyst, you are responsible for researching and interpreting data....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Washington+DC', 'Data Analytics Specialist', 'PCAOB', 'Nothing_found', 'Data analysis, quantitative:. The individual in this role will work closely with other divisions, inspection teams, data scientists, key management and...', 'PCAOB\n\n\n15 reviews']
# job post length:
# 6
# page: 0
# job post:
# ['Boulder', 'Data Scientist', 'Transamerica', 'Nothing_found', 'As part of the Advanced Analytics group, the Data Scientist works with product managers, data engineers, and other data scientists to develop innovative...', 'Transamerica\n\n\n621 reviews']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist / Broomfield, CO / $50hr / Contract-to-Hire', 'Vaco - Nashville', 'Nothing_found', 'Data scientists use data and analytical ability to find and interpret rich data sources; Merge data sources;...', 'Vaco - Nashville']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Engineer', 'Transamerica', 'Nothing_found', 'Partner with data scientists, analytics engagement managers, and other data engineers to discover, collect, cleanse, and refine the data needed for analysis and...', 'Transamerica\n\n\n621 reviews']
# job post length:
# 6
# job post:
# ['Boulder', 'Machine Learning Engineer', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist / Broomfield, CO / $50hr / Contract-to-Hire', 'Vaco', 'Nothing_found', 'Data scientists use data and analytical ability to find and interpret rich data sources; Merge data sources; Ensure consistency of data sets;...', 'Vaco\n\n\n186 reviews']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist', 'Indeed Prime', 'Nothing_found', "Indeed Prime is a free service that connects qualified job-seekers (that's you) with top companies hiring tech roles. With one application you can be...", 'Indeed Prime']
# job post length:
# 6
# job post:
# ['Boulder', 'Aquatic Instrumentation Scientist', 'Battelle', 'Nothing_found', 'The position will develop, document, and analyze data for data comparison, availability, and validation tests for NEON AIS data products....', 'Battelle\n\n\n291 reviews']
# job post length:
# 6
# job post:
# ['Boulder', 'Administrative Associate II (665026)', 'Ball Aerospace', 'Boulder, CO', 'Our team of more than 3,000 engineers, scientists, technicians and support staff drives all the achievements at Ball Aerospace....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist', 'Ace Technologies', 'Broomfield, CO', 'Data scientists use data and analytical ability to find and interpret rich data sources; Merge data sources; Ensure consistency of data sets;...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Medical Data Entry/Accessioning Analysis', 'LabCorp', 'Denver, CO', 'Proficient data entry skills. Prepares laboratory specimens for designated departments/locations prior to laboratory analysis and testing....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Product Manager, Data', 'Recurly', 'Boulder, CO', 'Craft data products that will help address customer needs - whether that is adding new data into the data warehouse, enhancing dashboards and visualizations, or...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Associate Scientist II', 'UCAR', 'Boulder, CO', 'Associate Scientist II. Monitoring incoming data sets submitted by external collaborators and working with external collaborators to resolve any problems with...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Environmental Data\xa0Management\xa0Specialist', 'Formation Environmental', 'Boulder, CO 80301', 'Perform data quality checks. Interact with laboratory contacts with data questions. Produce final report tables for project managers, scientists, and engineers....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist', 'Pricesenz', 'Denver, CO', 'Data scientists use data and analytical ability to find and interpret rich data sources; Merge data sources; Ensure consistency of data sets;...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist', 'Creative Alignments', 'Boulder, CO', 'Qualifications for Data Scientist. Use our wealth of data sources, such as energy usage, marketing data, and premise data to personalize the customer experience...', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Data Scientist', 'Blue Bird Technologies Pvt. Ltd.', 'Broomfield, CO', 'Assist in analyzing and visualizing moderately complex and unique data sets. Making the best decisions possible given the data quality and time available....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Jr. Data Scientist', 'AdAction', 'Denver, CO', 'Data Scientist to join our Data Science team. 3+ years of experience as an analyst, data scientist, or related quantitative role....', 'Nothing_found']
# job post length:
# 6
# job post:
# ['Boulder', 'Research Scientist-Audio Vision (Emerging Technologies)', 'Sensory, Inc', 'Nothing_found', 'Experience in data analysis and utilization of machine-learning techniques (including deep-learning) to solve pattern classification problems....', 'Sensory, Inc']
# job post length:
# 6
# job post:
# ['Boulder', 'Research Scientist (Vision Technology)', 'Sensory, Inc', 'Nothing_found', 'Research Scientist (Vision Technology). As a Research Scientist within Sensory’s Vision Technologies team, you will bring your intelligence and drive to our...', 'Sensory, Inc']
# job post length:
# 6

# %%
sample_df
# Out:
#               city                                          job_title  \
# 1         New+York                                     Data Scientist
# 2         New+York                                     Data Scientist
# 3         New+York                        Quantitative Data Scientist
# 4         New+York                              AI Research Scientist
# 5         New+York                                     Data Scientist
# 6         New+York        Associate Data Scientist, Premium Analytics
# 7         New+York                                 Data/NLP Scientist
# 8         New+York                       Data Scientist Summer Intern
# 9         New+York                      Data Scientist, Intern (2019)
# 10        New+York                           ASSOCIATE DATA SCIENTIST
# 11        New+York                              Data Scientist Intern
# 12        New+York                            Analyst | Data Analysis
# 13        New+York  Competitions Programs Specialist, Talent Progr...
# 14        New+York                                     Data Scientist
# 15        New+York                           Associate Data Scientist
# 16        New+York                                 R&D Scientist, Jr.
# 17         Chicago                      Arity - Data Scientist Intern
# 18         Chicago                                     Data Scientist
# 19         Chicago                          Machine Learning Engineer
# 20         Chicago                                     Data Scientist
# 21         Chicago    Data Analyst - Entry-Level - Technology Startup
# 22         Chicago                                     Data Scientist
# 23         Chicago                           Junior Variant Scientist
# 24         Chicago                                 Decision Scientist
# 25         Chicago                              Data Scientist Intern
# 26         Chicago                Jr. Clinical Trials Data Specialist
# 27         Chicago                                    Staff Scientist
# 28         Chicago                           Health Care Data Analyst
# 29         Chicago                     Data Scientist - Life Sciences
# 30         Chicago                                     Data Scientist
# ..             ...                                                ...
# 253  Washington+DC                                     Student Fellow
# 254  Washington+DC                     Health Scientist (Informatics)
# 255  Washington+DC          Graduate Studies Program - Data Scientist
# 256  Washington+DC                     INFORMS Data Job Opportunities
# 257  Washington+DC                                     Data Scientist
# 258  Washington+DC                                     Data Scientist
# 259  Washington+DC                                Associate/Scientist
# 260  Washington+DC                              HP032 Data Technician
# 261  Washington+DC                                   Research Analyst
# 262  Washington+DC                          Machine Learning Engineer
# 263  Washington+DC                          Data Analytics Specialist
# 264        Boulder                                     Data Scientist
# 265        Boulder  Data Scientist / Broomfield, CO / $50hr / Cont...
# 266        Boulder                                      Data Engineer
# 267        Boulder                          Machine Learning Engineer
# 268        Boulder  Data Scientist / Broomfield, CO / $50hr / Cont...
# 269        Boulder                                     Data Scientist
# 270        Boulder                  Aquatic Instrumentation Scientist
# 271        Boulder               Administrative Associate II (665026)
# 272        Boulder                                     Data Scientist
# 273        Boulder           Medical Data Entry/Accessioning Analysis
# 274        Boulder                              Product Manager, Data
# 275        Boulder                             Associate Scientist II
# 276        Boulder           Environmental Data Management Specialist
# 277        Boulder                                     Data Scientist
# 278        Boulder                                     Data Scientist
# 279        Boulder                                     Data Scientist
# 280        Boulder                                 Jr. Data Scientist
# 281        Boulder  Research Scientist-Audio Vision (Emerging Tech...
# 282        Boulder             Research Scientist (Vision Technology)
#
#                                     company_name  \
# 1                             Fora Financial LLC
# 2                                Liberty Lending
# 3                                        Harnham
# 4                                      Bloomberg
# 5                                SupplyHouse.com
# 6                                        Spotify
# 7                         Storm Global Analytics
# 8                                         WeWork
# 9                                       1010data
# 10                             Foot Locker, Inc.
# 11                                      Raindrop
# 12   New York City OFFICE OF MANAGEMENT & BUDGET
# 13                                        Google
# 14                               Rent the Runway
# 15                          Church Pension Group
# 16              Chembio Diagnostic Systems, Inc.
# 17                                      Allstate
# 18                                         Crowe
# 19                                  Indeed Prime
# 20                                  Indeed Prime
# 21                               Enterprise Peak
# 22                               Civis Analytics
# 23                                        Tempus
# 24                   Resource Systems Group Inc.
# 25                   Brookfield Asset Management
# 26                                        Tempus
# 27                     The University of Chicago
# 28             NORC at the University of Chicago
# 29                   Argonne National Laboratory
# 30                                     Wunderman
# ..                                           ...
# 253   Transparency and Accountability Initiative
# 254                                          CDC
# 255                  Central Intelligence Agency
# 256               Institute for Defense Analyses
# 257                          Booz Allen Hamilton
# 258                           Elder Research Inc
# 259                                     Exponent
# 260                          ADNET Systems, Inc.
# 261                                  Jacob’s Eye
# 262                                 Indeed Prime
# 263                                        PCAOB
# 264                                 Transamerica
# 265                             Vaco - Nashville
# 266                                 Transamerica
# 267                                 Indeed Prime
# 268                                         Vaco
# 269                                 Indeed Prime
# 270                                     Battelle
# 271                               Ball Aerospace
# 272                             Ace Technologies
# 273                                      LabCorp
# 274                                      Recurly
# 275                                         UCAR
# 276                      Formation Environmental
# 277                                    Pricesenz
# 278                          Creative Alignments
# 279             Blue Bird Technologies Pvt. Ltd.
# 280                                     AdAction
# 281                                 Sensory, Inc
# 282                                 Sensory, Inc
#
#                                     location  \
# 1                              Nothing_found
# 2                              Nothing_found
# 3                              Nothing_found
# 4                              Nothing_found
# 5                               Melville, NY
# 6          New York, NY 10011 (Chelsea area)
# 7                               New York, NY
# 8                               New York, NY
# 9                               New York, NY
# 10                              New York, NY
# 11                              New York, NY
# 12                             Manhattan, NY
# 13         New York, NY 10011 (Chelsea area)
# 14                              New York, NY
# 15                             Nothing_found
# 16                             Nothing_found
# 17                             Nothing_found
# 18                             Nothing_found
# 19                             Nothing_found
# 20                             Nothing_found
# 21                               Chicago, IL
# 22                               Chicago, IL
# 23                               Chicago, IL
# 24             Chicago, IL 60601 (Loop area)
# 25                               Chicago, IL
# 26             Chicago, IL 60654 (Loop area)
# 27                               Chicago, IL
# 28                               Chicago, IL
# 29                                Lemont, IL
# 30                               Chicago, IL
# ..                                       ...
# 253                           Washington, DC
# 254                          Hyattsville, MD
# 255                           Washington, DC
# 256                           Alexandria, VA
# 257                           Washington, DC
# 258  Arlington, VA 22201 (Lyon Village area)
# 259                                Bowie, MD
# 260                      Greenbelt, MD 20771
# 261                           Washington, DC
# 262                            Nothing_found
# 263                            Nothing_found
# 264                            Nothing_found
# 265                            Nothing_found
# 266                            Nothing_found
# 267                            Nothing_found
# 268                            Nothing_found
# 269                            Nothing_found
# 270                            Nothing_found
# 271                              Boulder, CO
# 272                           Broomfield, CO
# 273                               Denver, CO
# 274                              Boulder, CO
# 275                              Boulder, CO
# 276                        Boulder, CO 80301
# 277                               Denver, CO
# 278                              Boulder, CO
# 279                           Broomfield, CO
# 280                               Denver, CO
# 281                            Nothing_found
# 282                            Nothing_found
#
#                                                summary  \
# 1    A Day in the Life of a Data Scientist:. Identi...
# 2    Data scientist to work as a statistician, data...
# 3    Quantatative Data Scientist. Their top priorit...
# 4    The infrastructure and algorithms we develop a...
# 5    Discover new data points and validate existing...
# 6    You will work with a global team of world-clas...
# 7    Design NLP models for searching structured/uns...
# 8    Comfortable with quantitative analysis, statis...
# 9    1010data is a highly differentiated product th...
# 10   The Associate Data Scientist assists the team ...
# 11   Good communication skills, and experience tell...
# 12   Data AnalysisJOB TITLE:. Provide assistance to...
# 13   Manage the ongoing reporting and data analysis...
# 14   Mine the data ecosystem & find fruitful signal...
# 15   The Associate Data Scientist will work closely...
# 16   The Junior Scientist is responsible for perfor...
# 17   The Data Scientist family is accountable for u...
# 18   Collaborate with analytic and data teams to se...
# 19   Indeed Prime is a free service that connects q...
# 20   Indeed Prime is a free service that connects q...
# 21   Data Analyst Responsibilities:. The Data Analy...
# 22   Experience working with imperfect data. At Civ...
# 23   We now have more data than ever before, but pr...
# 24   Data Visualization experience. AS A DECISION S...
# 25   Data Scientist Intern. Help the team automate ...
# 26   We now have more data than ever before, but pr...
# 27   A Staff Scientist is responsible for all aspec...
# 28   At NORC, Data Analysts work with our Data Scie...
# 29   Problems typically involve the construction of...
# 30   Support Lead Data Scientist in delivering a wi...
# ..                                                 ...
# 253  Building on successes to date, which include p...
# 254  As a Health Scientist (Informatics) you will:....
# 255  As a Data Scientist Graduate Intern for the CI...
# 256  We are seeking data scientists to support the ...
# 257  As a data scientist, you can turn these comple...
# 258  While we do not have any openings for Data Sci...
# 259  Our multidisciplinary team of scientists, engi...
# 260  HP032 Junior Data Technician, Part Time. We ar...
# 261  Providing suitable data to determine whether t...
# 262  Indeed Prime is a free service that connects q...
# 263  Data analysis, quantitative:. The individual i...
# 264  As part of the Advanced Analytics group, the D...
# 265  Data scientists use data and analytical abilit...
# 266  Partner with data scientists, analytics engage...
# 267  Indeed Prime is a free service that connects q...
# 268  Data scientists use data and analytical abilit...
# 269  Indeed Prime is a free service that connects q...
# 270  The position will develop, document, and analy...
# 271  Our team of more than 3,000 engineers, scienti...
# 272  Data scientists use data and analytical abilit...
# 273  Proficient data entry skills. Prepares laborat...
# 274  Craft data products that will help address cus...
# 275  Associate Scientist II. Monitoring incoming da...
# 276  Perform data quality checks. Interact with lab...
# 277  Data scientists use data and analytical abilit...
# 278  Qualifications for Data Scientist. Use our wea...
# 279  Assist in analyzing and visualizing moderately...
# 280  Data Scientist to join our Data Science team. ...
# 281  Experience in data analysis and utilization of...
# 282  Research Scientist (Vision Technology). As a R...
#
#                                               salary
# 1                 Fora Financial LLC\n\n\n20 reviews
# 2                                    Liberty Lending
# 3                             Harnham\n\n\n6 reviews
# 4                         Bloomberg\n\n\n670 reviews
# 5                                      Nothing_found
# 6                                      Nothing_found
# 7                                      Nothing_found
# 8                                      Nothing_found
# 9                                      Nothing_found
# 10                                     Nothing_found
# 11                                     Nothing_found
# 12                                     Nothing_found
# 13                                     Nothing_found
# 14                                     Nothing_found
# 15              Church Pension Group\n\n\n23 reviews
# 16   Chembio Diagnostic Systems, Inc.\n\n\n7 reviews
# 17                       Allstate\n\n\n5,668 reviews
# 18                            Crowe\n\n\n183 reviews
# 19                                      Indeed Prime
# 20                                      Indeed Prime
# 21                                     Nothing_found
# 22                                     Nothing_found
# 23                                     Nothing_found
# 24                                     Nothing_found
# 25                                     Nothing_found
# 26                                     Nothing_found
# 27                                     Nothing_found
# 28                                     Nothing_found
# 29                                     Nothing_found
# 30                                     Nothing_found
# ..                                               ...
# 253                                    Nothing_found
# 254                                    Nothing_found
# 255                                    Nothing_found
# 256                                    Nothing_found
# 257                                    Nothing_found
# 258                                    Nothing_found
# 259                                    Nothing_found
# 260                                    Nothing_found
# 261                                    Nothing_found
# 262                                     Indeed Prime
# 263                            PCAOB\n\n\n15 reviews
# 264                    Transamerica\n\n\n621 reviews
# 265                                 Vaco - Nashville
# 266                    Transamerica\n\n\n621 reviews
# 267                                     Indeed Prime
# 268                            Vaco\n\n\n186 reviews
# 269                                     Indeed Prime
# 270                        Battelle\n\n\n291 reviews
# 271                                    Nothing_found
# 272                                    Nothing_found
# 273                                    Nothing_found
# 274                                    Nothing_found
# 275                                    Nothing_found
# 276                                    Nothing_found
# 277                                    Nothing_found
# 278                                    Nothing_found
# 279                                    Nothing_found
# 280                                    Nothing_found
# 281                                     Sensory, Inc
# 282                                     Sensory, Inc
#
# [282 rows x 6 columns]

# %%
# Out:
# <Response [200]>
# C:\Users\Larissa\Anaconda3\lib\site-packages\bs4\__init__.py:146: UserWarning: You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.
#   warnings.warn("You provided Unicode markup but also provided a value for from_encoding. Your from_encoding will be ignored.")
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# 1
# ['Toronto', 'Pathology Surveyor', 'The Joint Commission', 'Analyzes all data submitted by the organization. Ability to critically review and analyze performance measurement data....', 'The Joint Commission\n\n\n58 reviews']
# 5
# 1
# ['Toronto', 'Geologist - Unconventional Resources (Relocation to Saudi Arabia)', 'Saudi Aramco', 'Of primary interest is experience in acquiring appropriate subsurface data integrated with seismic data to enable the identification of the most prospective...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'DSoft Technology is seeking Operations Research Analysts to support and assist the Headquarters Air Force Space Command with analysis of space systems...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'Contribute to the design and testing of new or enhanced staffing methodologies; evaluate the costs/benefits, present findings, and support the scaling of...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Time management and organizational skills necessary to appropriately prioritize workload, plan for resources to meet deadlines and goals, and respond to...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Responsible for descriptive, predictive, prescriptive and ensemble modeling, advanced statistical techniques, use of databases tools and/or other approaches...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'Manage ESRI’s ArcGIS Platform at Dick’s Sporting Goods including ArcGIS Desktop, ArcGIS online, ArcGIS Server and SQL server database by working with key...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Main responsibilities include: analysis of industrial-sized data sets to determine suitability for model building; identify opportunities for data...', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'This position will be responsible for closing new business across verticals including ADAS/AD, Agricultural, Industrial and Infrastructure.', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL.', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Collaborating with and supporting Pythian sales teams in the pre-sales & account management process from the technical perspective, remotely and on-site...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'Experience with multivariate predictive models in addition to 4+ years of Commercial P&C actuarial modeling is desired.', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'As a BI Engineer (m/f) in the Data Analytics & Insights, you will be responsible for designing, deploying and maintaining the data warehousing, reporting and...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'DSoft Technology is seeking Operations Research Analysts to support and assist the Headquarters Air Force Space Command with analysis of space systems...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'Contribute to the design and testing of new or enhanced staffing methodologies; evaluate the costs/benefits, present findings, and support the scaling of...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Time management and organizational skills necessary to appropriately prioritize workload, plan for resources to meet deadlines and goals, and respond to...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Responsible for descriptive, predictive, prescriptive and ensemble modeling, advanced statistical techniques, use of databases tools and/or other approaches...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'Manage ESRI’s ArcGIS Platform at Dick’s Sporting Goods including ArcGIS Desktop, ArcGIS online, ArcGIS Server and SQL server database by working with key...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Main responsibilities include: analysis of industrial-sized data sets to determine suitability for model building; identify opportunities for data...', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'This position will be responsible for closing new business across verticals including ADAS/AD, Agricultural, Industrial and Infrastructure.', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL.', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Collaborating with and supporting Pythian sales teams in the pre-sales & account management process from the technical perspective, remotely and on-site...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'Experience with multivariate predictive models in addition to 4+ years of Commercial P&C actuarial modeling is desired.', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'As a BI Engineer (m/f) in the Data Analytics & Insights, you will be responsible for designing, deploying and maintaining the data warehousing, reporting and...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ...
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
# <Response [200]>
# 1
# ['Toronto', 'Operations Research Analyst with DoD Secret or TS Clearance', 'DSoft Technology, Engineering and Analysis, Inc.', 'Collect and analyze data and develop decision support software, service, or products. Candidates with degrees similar to Operations Research such as Management...', 'DSoft Technology, Engineering and Analysis, Inc.']
# 5
# 1
# ['Toronto', 'Data Scientist - Labor Planning & Analytics', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The data scientist supports internal operations and the field organization by providing detailed analyses of in-store staffing and corresponding business...', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Operations Research Scientist', 'Fedex Ground', 'Township of Moon, PA 15108', 'Demonstrated knowledge of Operations Research (OR), mathematical and data modeling. Auto req ID:....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'Data Scientist', 'FedEx Services', 'FedEx ', 'Coraopolis, PA', 'Demonstrated skill at data cleansing, data quality assessment, and using analytics for data assessment. Collaborates with all Data and Analytic Principal...', 'Nothing_found']
# 7
# 1
# ['Toronto', 'Market Research Analyst - Technical', "DICK'S Sporting Goods", 'Coraopolis, PA 15108', 'The analyst will work together with Technology to make necessary changes including software / data updates and database changes....', 'Nothing_found']
# 6
# 1
# ['Toronto', 'AML/KYC Data Scientist', 'IBM', 'Familiar with several data and big data tools. The Data Scientist creates, tests and validates hypotheses for business problems....', 'IBM\n\n\n23,463 reviews']
# 5
# 1
# ['Toronto', 'Sales Account Executive - Machine Learning – (Remote)', 'Cvedia PTE. LTD.', 'CVEDIA helps develop and deploy autonomous systems today. Our suite of tools substantively accelerates the time to train, test and validate neural network...', 'Cvedia PTE. LTD.']
# 5
# 1
# ['Toronto', 'Data Scientist (Relocation to Saudi Arabia)', 'Saudi Aramco', 'The Data Scientist primary role is to implement solutions using advanced data analytics, such as in predicting future conditions, conducting correlation...', 'Saudi Aramco\n\n\n681 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary – Multiple Positions Available', 'DW Simpson Global Actuarial Recruitment', 'Well-known client seeks an ACAS or FCAS with 2+ years of multivariate predictive modeling experience, along with a high degree of proficiency with SAS and SQL...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Google Cloud Solutions Architect', 'Pythian', 'Prior experience working as/with Machine Learning Engineers, Data Engineers, or Data Scientists. Do you have Big data and Data centric skills?...', 'Pythian\n\n\n10 reviews']
# 5
# 1
# ['Toronto', 'Predictive Modeling Actuary, P&C', 'DW Simpson Global Actuarial Recruitment', 'The ideal candidate has advanced degree such as a PhD or ACAS/FCAS designation. Experience with multivariate predictive models in addition to 4+ years of...', 'DW Simpson Global Actuarial Recruitment']
# 5
# 1
# ['Toronto', 'Business Intelligence Engineer (f/m) (relocated to Germany)', 'Avira Operations GmbH & Co. KG', 'Experience in data migration and data integration. You will work together with big data engineers, machine learning engineers and data scientists, and develop...', 'Avira Operations GmbH & Co. KG']
# 5
